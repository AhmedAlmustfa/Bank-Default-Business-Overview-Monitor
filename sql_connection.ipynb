# %%
from sqlalchemy import create_engine

# Replace with YOUR actual string from Neon
DB = "postgresql://neondb_owner:npg_xR7Yrw4GiVJF@ep-autumn-field-ab2su58p-pooler.eu-west-2.aws.neon.tech/neondb?sslmode=require&channel_binding=require" 
engine = create_engine(DB)

try:
    with engine.connect() as conn:
        print("Connection Successful! Your database is ready.")
except Exception as e:
    print(f"Connection Failed: {e}")
# Out:
# Connection Successful! Your database is ready.
